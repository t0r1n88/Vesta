# %%
import pandas as pd
import datetime
import os
import warnings

warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')
warnings.simplefilter(action='ignore', category=DeprecationWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
pd.options.mode.chained_assignment = None

# %%
path_to_data = 'data/07.08.23'

# %%
form1_df = pd.DataFrame(columns=range(22))
form2_df = pd.DataFrame(columns=range(11))
form3_df = pd.DataFrame(columns=range(8))

# %%
for file in os.listdir(path_to_data):
    print(file)
    # обрабатываем первый лист
    temp_df = pd.read_excel(f'{path_to_data}/{file}',sheet_name='Форма по мониторингу',dtype={'гр.2':str},skiprows=2,usecols='A:V')
    temp_df.columns = range(22)
    temp_df.dropna(thresh=6,inplace=True)
    form1_df = pd.concat([form1_df,temp_df],ignore_index=True)
    
    # обрабатываем второй лист
    temp_df = pd.read_excel(f'{path_to_data}/{file}',sheet_name='Форма по принимаемым мерам',dtype={'гр.2':str},skiprows=2,usecols='A:K')
    temp_df.columns = range(11)
    temp_df.dropna(thresh=6,inplace=True)
    form2_df = pd.concat([form2_df,temp_df],ignore_index=True)
    
    #обрабатываем третий лист
    temp_df = pd.read_excel(f'{path_to_data}/{file}',sheet_name='Форма по социальной поддежке',dtype={'гр.2':str},skiprows=2,usecols='A:H')
    temp_df.columns = range(8)
    temp_df.dropna(thresh=6,inplace=True)
    form3_df = pd.concat([form3_df,temp_df],ignore_index=True)
# Out:
# Амурская область_07.08.2023.xlsx
# Бурятия.xlsx
# Забайкальский край 07.08.xlsx
# Камчатка.xlsx
# Магадан.xlsx
# Примосркий край_07.08.xlsx
# РС (Я).xlsx
# Сахалин.xlsx
# Хабаровский край_ОПК_07.08.2023.xlsx

# %%
with pd.ExcelWriter('data/Тесто.xlsx') as writer:
    form1_df.to_excel(writer,sheet_name='Форма по мониторингу',index=False)
    form2_df.to_excel(writer,sheet_name='Форма по принимаемым мерам',index=False)
    form3_df.to_excel(writer,sheet_name='Форма по социальной поддежке',index=False)

# %%
temp_df = pd.read_excel('data/07.08.23/Бурятия.xlsx',dtype={'гр.2':str},skiprows=2)
# Out:
# C:\Users\1\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\1\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
temp_df.dropna(thresh=4).to_excel('dgf.xlsx',index=False
                                 )
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24192\1016202066.py in <module>
# ----> 1 temp_df.dropna(thresh=4).to_excel('dgf.xlsx',index=False
#       2                                  )
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...

# %%
temp_df = pd.read_excel('data/07.08.23/Бурятия.xlsx',sheet_name='Форма по принимаемым мерам',dtype={'гр.2':str},skiprows=2)
# Out:
# C:\Users\1\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
temp_df
# Out:
#                  гр. 1        гр.2  \
# 0   Республика Бурятия  0323018510
# 1   Республика Бурятия  0302001219
# 2   Республика Бурятия  0306229060
# 3   Республика Бурятия  0323007941
# 4   Республика Бурятия  0323025958
# 5   Республика Бурятия  0326497719
# 6   Республика Бурятия  0326551807
# 7   Республика Бурятия  0323053578
# 8   Республика Бурятия  0326568462
# 9   Республика Бурятия  7706196340
# 10  Республика Бурятия  7718766718
# 11  Республика Бурятия  7718766718
# 12                 NaN         NaN
# 13                 NaN         NaN
# 14                 NaN         NaN
# 15                 NaN         NaN
# 16                 NaN         NaN
# 17                 NaN         NaN
# 18                 NaN         NaN
# 19                 NaN         NaN
# 20                 NaN         NaN
# 21                 NaN         NaN
# 22                 NaN         NaN
# 23                 NaN         NaN
# 24                 NaN         NaN
# ...

# %%
temp_df.dropna(thresh=4).to_excel('2.xlsx',index=False
                                 )
